# %%
import pandas as pd

# %%
df=pd.read_csv('stackoverflow/survey_results_public.csv',index_col='Respondent')
df.head(5)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df=pd.read_csv('stackoverflow/survey_results_schema.csv',index_col='Column')
schema_df.head(5)
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
#change ConvertedComp to SalaryByUSD
df.rename(columns = {'ConvertedComp':'SalaryByUSD'},inplace=True)
df['SalaryByUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryByUSD, Length: 64461, dtype: float64

# %%
#change ConvertedComp to SalaryByUSD in schema file
schema_df.rename(index = {'ConvertedComp':'SalaryByUSD'},inplace = True)
schema_df.loc['SalaryByUSD']
# Out:
# QuestionText    Salary converted to annual USD salaries using ...
# Name: SalaryByUSD, dtype: object

# %%
#change data of two cells
df.loc[[1,2],'SalaryByUSD']='NA'

# %%
#change the values of many columns for one row
# here we will change the value of age and CompTotal for the first row
df.loc[1,['Age','CompTotal']]=['NA','NA']
df.head(1)
# Out:
#                                 MainBranch Hobbyist Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NA         13  Monthly
#
#            CompTotal SalaryByUSD  Country   CurrencyDesc CurrencySymbol  ...  \
# Respondent                                                               ...
# 1                 NA          NA  Germany  European Euro            EUR  ...
#
#                             SurveyEase           SurveyLength Trans  \
# Respondent
# 1           Neither easy nor difficult  Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
#
#                                       WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# ...

# %%
#edit data using filter
# edit the data where the column values equal to 'Syrian Arab Republic'
#replace it with 'Syria'
my_filter = (df["Country"] == 'Syrian Arab Republic')
df.loc[my_filter,'Country']='Syria'
my_filter = (df["Country"] == 'Syria')
df.loc[my_filter].head(2)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 868         I am not primarily a developer, but I write co...       No  25.0
# 12250                          I am a developer by profession      Yes  21.0
#
#            Age1stCode CompFreq CompTotal SalaryByUSD Country  CurrencyDesc  \
# Respondent
# 868                15  Monthly  100000.0      2328.0   Syria  Syrian pound
# 12250              12  Monthly  125000.0      2916.0   Syria  Syrian pound
#
#            CurrencySymbol  ... SurveyEase           SurveyLength Trans  \
# Respondent                 ...
# 868                   SYP  ...       Easy  Appropriate in length    No
# 12250                 SYP  ...       Easy  Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 868         Information systems, information technology, o...
# 12250       Computer science, computer engineering, or sof...
#
# ...

# %%
#Change the CurrencySymbol to lowercase
df['CurrencySymbol']=df['CurrencySymbol'].apply(lambda x:str(x).upper())
df['CurrencySymbol']
# Out:
# Respondent
# 1        EUR
# 2        GBP
# 3        NAN
# 4        ALL
# 5        NAN
#         ...
# 64858    NAN
# 64867    NAN
# 64898    NAN
# 64925    NAN
# 65112    NAN
# Name: CurrencySymbol, Length: 64461, dtype: object

# %%
# Change the CurrencySymbol to uppercase
df['CurrencySymbol'] = df['CurrencySymbol'].str.upper()
df['CurrencySymbol']
# Out:
# Respondent
# 1        EUR
# 2        GBP
# 3        NAN
# 4        ALL
# 5        NAN
#         ...
# 64858    NAN
# 64867    NAN
# 64898    NAN
# 64925    NAN
# 65112    NAN
# Name: CurrencySymbol, Length: 64461, dtype: object

# %%
# using applymap() with dataframe, and changing all the data to lowercase.
df.applymap(lambda x:str(x).lower())
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              i am a developer by profession      yes    na
# 2                              i am a developer by profession       no   nan
# 3                                 i code primarily as a hobby      yes   nan
# 4                              i am a developer by profession      yes  25.0
# 5           i used to be a developer by profession, but no...      yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     nan      yes   nan
# 64867                                                     nan      yes   nan
# 64898                                                     nan      yes   nan
# 64925                                                     nan      yes   nan
# 65112                                                     nan      yes   nan
#
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes    NA
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
# using map() with series object
# change value of 'Hobbyist' -----  yes => True, no => False
# we cannot user inplace with map
# so to store the result we assign it
# df['Hobbyist'] = df['Hobbyist'].map({'Yes':'True','No':'False'})
df['Hobbyist'].map({'Yes':'True','No':'False'})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
#merging two column
df['MajorAndUsedLanguages'] = df['MainBranch'] + '\\' + df['WebframeWorkedWith']
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes   NA         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#            CompTotal SalaryByUSD         Country    CurrencyDesc  \
# Respondent
# 1                 NA          NA         Germany   European Euro
# 2                NaN          NA  United Kingdom  Pound sterling
#
#            CurrencySymbol  ... Trans  \
# Respondent                 ...
# 1                     EUR  ...    No
# 2                     GBP  ...   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# ...

# %%
# Delete column
df.drop(columns='MajorAndUsedLanguages',inplace = True)

# %%
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes   NA         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#            CompTotal SalaryByUSD         Country    CurrencyDesc  \
# Respondent
# 1                 NA          NA         Germany   European Euro
# 2                NaN          NA  United Kingdom  Pound sterling
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# 2                     GBP  ...                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# ...

# %%
#imporve the data of WebframeWorkedWith data
df['WebframeWorkedWith'] = df['WebframeWorkedWith'].str.replace(';',', ')
df['WebframeWorkedWith']
# Out:
# Respondent
# 1                            ASP.NET, ASP.NET Core
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                    Ruby on Rails
#                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                          NaN
# 65112    Angular, Angular.js, ASP.NET Core, jQuery
# Name: WebframeWorkedWith, Length: 64461, dtype: object

# %%
#merging two DataFrames
df.append(schema_df)
# Out:
#                                                            MainBranch  \
# 1                                      I am a developer by profession
# 2                                      I am a developer by profession
# 3                                         I code primarily as a hobby
# 4                                      I am a developer by profession
# 5                   I used to be a developer by profession, but no...
# ...                                                               ...
# WebframeWorkedWith                                                NaN
# WelcomeChange                                                     NaN
# WorkWeekHrs                                                       NaN
# YearsCode                                                         NaN
# YearsCodePro                                                      NaN
#
#                    Hobbyist   Age Age1stCode CompFreq CompTotal SalaryByUSD  \
# ...
