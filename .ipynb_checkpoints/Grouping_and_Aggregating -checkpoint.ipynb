# %%
import pandas as pd

# %%
df = pd.read_csv('stackoverflow/survey_results_public.csv',index_col='Respondent')
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# 2                     GBP  ...                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# ...

# %%
# the median of the values for every column
df.median()
# Out:
# C:\Users\ahmed\AppData\Local\Temp/ipykernel_12224/129262512.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
# the median of the salary column
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
# the number of valid data for every column
df.count()
# Out:
# MainBranch                      64162
# Hobbyist                        64416
# Age                             45446
# Age1stCode                      57900
# CompFreq                        40069
# CompTotal                       34826
# ConvertedComp                   34756
# Country                         64072
# CurrencyDesc                    45472
# CurrencySymbol                  45472
# DatabaseDesireNextYear          44070
# DatabaseWorkedWith              49537
# DevType                         49370
# EdLevel                         57431
# Employment                      63854
# Ethnicity                       45948
# Gender                          50557
# JobFactors                      49349
# JobSat                          45194
# JobSeek                         51727
# LanguageDesireNextYear          54113
# LanguageWorkedWith              57378
# MiscTechDesireNextYear          42379
# MiscTechWorkedWith              40314
# NEWCollabToolsDesireNextYear    47287
# ...

# %%
#analyse and explore the data
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
# how many people are Hobbyist
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                                                                  4770
# Linux;Windows                                                                                                            2461
# Linux                                                                                                                    2112
# Android                                                                                                                  1201
# Microsoft Azure;Windows                                                                                                   996
#                                                                                                                          ...
# AWS;Docker;Heroku;Kubernetes;MacOS;Windows;WordPress                                                                        1
# ...

# %%
#What was the primary field of study for the participated programmer?\percentage\
df['UndergradMajor'].value_counts(normalize = True)
# Out:
# Computer science, computer engineering, or software engineering                   0.619316
# Another engineering discipline (such as civil, electrical, mechanical, etc.)      0.093225
# Information systems, information technology, or system administration             0.079831
# A natural science (such as biology, chemistry, physics, etc.)                     0.043240
# Mathematics or statistics                                                         0.036258
# Web development or web design                                                     0.035082
# A business discipline (such as accounting, finance, marketing, etc.)              0.026963
# A humanities discipline (such as literature, history, philosophy, etc.)           0.019747
# A social science (such as anthropology, psychology, political science, etc.)      0.018296
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)    0.014217
# ...

# %%
# first split the object then apply the get_group() function.
Country_group_by = df.groupby(['Country'])
Country_group_by.get_group('Syrian Arab Republic')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 868         I am not primarily a developer, but I write co...       No  25.0
# 12250                          I am a developer by profession      Yes  21.0
# 12541                          I am a developer by profession       No  27.0
# 17167                          I am a developer by profession      Yes  39.0
# 22043                  I am a student who is learning to code       No  22.0
# 27213                          I am a developer by profession      Yes  27.0
# 36504                             I code primarily as a hobby      Yes  18.0
# 37142                  I am a student who is learning to code      Yes  20.0
# 38816                          I am a developer by profession      Yes   NaN
# 43659                          I am a developer by profession       No  40.0
# 46515                  I am a student who is learning to code      Yes   NaN
# ...

# %%
# display the platforms which are using in developers in every country
Country_group_by['PlatformWorkedWith'].value_counts()
# Out:
# Country      PlatformWorkedWith
# Afghanistan  Android                                  7
#              Windows                                  5
#              Android;Windows                          4
#              Android;Linux;Windows;WordPress          3
#              Android;Google Cloud Platform;Windows    2
#                                                      ..
# Zimbabwe     Heroku;Linux;Raspberry Pi;WordPress      1
#              Heroku;Linux;WordPress                   1
#              Heroku;WordPress                         1
#              Linux                                    1
#              Linux;Windows                            1
# Name: PlatformWorkedWith, Length: 21897, dtype: int64

# %%
# display the platforms which are using in developers in Syria \using filter\
my_filter = df['Country'] == 'Syrian Arab Republic'
df.loc[my_filter]['PlatformWorkedWith'].value_counts()
# Out:
# Android                                    2
# Arduino;Linux                              1
# Linux;Windows                              1
# Android;Arduino;Windows                    1
# Linux                                      1
# Windows;WordPress                          1
# Android;Docker                             1
# Android;Heroku;Linux;Windows               1
# Android;Arduino;Linux;Windows;WordPress    1
# iOS;MacOS;Windows                          1
# Docker;Linux                               1
# Name: PlatformWorkedWith, dtype: int64

# %%
# display the platforms which are using in developers in Syria \using group\
Country_group_by['PlatformWorkedWith'].value_counts().loc['Syrian Arab Republic']
# Out:
# PlatformWorkedWith
# Android                                    2
# Android;Arduino;Linux;Windows;WordPress    1
# Android;Arduino;Windows                    1
# Android;Docker                             1
# Android;Heroku;Linux;Windows               1
# Arduino;Linux                              1
# Docker;Linux                               1
# Linux                                      1
# Linux;Windows                              1
# Windows;WordPress                          1
# iOS;MacOS;Windows                          1
# Name: PlatformWorkedWith, dtype: int64

# %%
# display the percentage of using platforms for every counntry
Country_group_by['PlatformWorkedWith'].value_counts(normalize = True)
# Out:
# Country      PlatformWorkedWith
# Afghanistan  Android                                  0.170732
#              Windows                                  0.121951
#              Android;Windows                          0.097561
#              Android;Linux;Windows;WordPress          0.073171
#              Android;Google Cloud Platform;Windows    0.048780
#                                                         ...
# Zimbabwe     Heroku;Linux;Raspberry Pi;WordPress      0.038462
#              Heroku;Linux;WordPress                   0.038462
#              Heroku;WordPress                         0.038462
#              Linux                                    0.038462
#              Linux;Windows                            0.038462
# Name: PlatformWorkedWith, Length: 21897, dtype: float64

# %%
# the average salary for every country
Country_group_by['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
# the average salary in Syria
Country_group_by['ConvertedComp'].median().loc['Syrian Arab Republic']
# Out:
# 2916.0

# %%
#Aggregation
# get the median and the mean of salary for the countries
Country_group_by['ConvertedComp'].agg(['median','mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
# get the median and the mean of salary in Syria
Country_group_by['ConvertedComp'].agg(['median','mean']).loc['Syrian Arab Republic']
# Out:
# median    2916.0
# mean      4833.6
# Name: Syrian Arab Republic, dtype: float64

# %%
# how many people know how to use python
Country_group_by['LanguageDesireNextYear'].apply(lambda x : x.str.contains('Python')).sum()
# Out:
# 26682
