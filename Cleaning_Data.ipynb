# %%
import pandas as pd

# %%
df = pd.read_csv('stackoverflow/survey_results_public.csv',index_col = 'Respondent')
df.head(4)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes   NaN         13  Monthly
# 2           I am a developer by profession       No   NaN         19      NaN
# 3              I code primarily as a hobby      Yes   NaN         15      NaN
# 4           I am a developer by profession      Yes  25.0         18      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
# 4                 NaN            NaN             Albania    Albanian lek
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# ...

# %%
# True where cell is NA
df.head(10).isna()
# Out:
#             MainBranch  Hobbyist    Age  Age1stCode  CompFreq  CompTotal  \
# Respondent
# 1                False     False   True       False     False       True
# 2                False     False   True       False      True       True
# 3                False     False   True       False      True       True
# 4                False     False  False       False      True       True
# 5                False     False  False       False      True       True
# 6                False     False   True       False      True       True
# 7                False     False   True       False     False       True
# 8                False     False  False       False     False      False
# 9                False     False  False       False      True       True
# 10               False     False  False       False     False      False
#
#             ConvertedComp  Country  CurrencyDesc  CurrencySymbol  ...  \
# Respondent                                                        ...
# ...

# %%
#fill the NA cells with 0
df.fillna(0)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
#the type of the data columns
df.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# Age1stCode                       object
# CompFreq                         object
# CompTotal                       float64
# ConvertedComp                   float64
# Country                          object
# CurrencyDesc                     object
# CurrencySymbol                   object
# DatabaseDesireNextYear           object
# DatabaseWorkedWith               object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# JobSeek                          object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# ...

# %%
# the mean of the age
df['Age'].mean()
# Out:
# 30.83411081283281

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %%
na_values= ['NA','Missing']
df = pd.read_csv('stackoverflow/survey_results_public.csv',index_col = 'Respondent')
len(df)
# Out:
# 64461

# %%
# clean data for the Years Code
df['YearsCode'].head(5)
# Out:
# Respondent
# 1    36
# 2     7
# 3     4
# 4     7
# 5    15
# Name: YearsCode, dtype: object

# %%
#the type is string so, we have to know what is it
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
#replace 'Less than 1 year' with zero and 'More than 50 years' with 51
df['YearsCode'].replace('Less than 1 year',0,inplace = True)
df['YearsCode'].replace('More than 50 years',51,inplace = True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].dtype
# Out:
# dtype('float64')
